# %% [markdown]
# ## Multiple plots
#
# The data set here comes from records of undergraduate degrees awarded to women in a variety of fields from 1970 to 2011. You can compare trends in degrees most easily by viewing two curves on the same set of axes.

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

# %%
data = pd.read_csv('./dataset/bachelors_women.csv', header= 0)

# %%
data.head()
# Out:
#    Year  Agriculture  Architecture  Art and Performance    Biology   Business  \
# 0  1970     4.229798     11.921005                 59.7  29.088363   9.064439
# 1  1971     5.452797     12.003106                 59.9  29.394403   9.503187
# 2  1972     7.420710     13.214594                 60.4  29.810221  10.558962
# 3  1973     9.653602     14.791613                 60.2  31.147915  12.804602
# 4  1974    14.074623     17.444688                 61.9  32.996183  16.204850
#
#    Communications and Journalism  Computer Science  Education  Engineering  \
# 0                           35.3              13.6  74.535328          0.8
# 1                           35.5              13.6  74.149204          1.0
# 2                           36.6              14.9  73.554520          1.2
# 3                           38.4              16.4  73.501814          1.6
# 4                           40.5              18.9  73.336811          2.2
#
# ...

# %%
plt.figure(figsize= (20,15))
data.plot(x = 'Year', y = ['Computer Science','Business'])
plt.show()

# %%
plt.close()
year = data['Year'].values
cs = data['Computer Science'].values
business = data['Business']
plt.figure(figsize=(10,5))
plt.plot(year, cs, color='blue')
plt.plot(year,business, color= 'red')
plt.legend(['Computer Science','Business'])
plt.xlabel('Year')
plt.ylabel('percentage')
plt.show()

# %% [markdown]
# ## Using axes()
# Rather than overlaying line plots on common axes, you may prefer to plot different line plots on distinct axes. The command plt.axes() is one way to do this (but it requires specifying coordinates relative to the size of the figure).
#
# You will use plt.axes() to create separate sets of axes in which you will draw each line plot.
#
# In calling plt.axes([xlo, ylo, width, height]), a set of axes is created and made active with lower corner at coordinates (xlo, ylo) of the specified width and height. Note that these coordinates can be passed to plt.axes() in the form of a list or a tuple.
#
# The coordinates and lengths are values between 0 and 1 representing lengths relative to the dimensions of the figure. After issuing a plt.axes() command, plots generated are put in that set of axes.

# %%
# Create plot axes for the first line plot
plt.axes([0.05,0.05,0.425,0.6])
plt.title('computer science plot')
plt.xlabel('year')
plt.ylabel('percentage')
# Plot in blue the % of degrees awarded to women in the Physical Sciences
plt.plot(year, cs, color='blue')

# Create plot axes for the second line plot
plt.axes([0.7,0.05,0.65,0.9])
plt.title('business plot')
plt.ylabel('percentage')
plt.xlabel('year')
# Plot in red the % of degrees awarded to women in Computer Science
plt.plot(year, business, color='red')

# Display the plot
plt.show()

# %%
plt.close()

# %% [markdown]
# ## Using subplot()
# other alternative is to use plt.subplot() to determine the layout automatically. However, in this cas you cannot configure the size of the each plot voluntary. Note that you have to specify the number of rows and columns that the plot will has. The function `plt.subplot()` expects by parameter a string with three digits. The first and second one correspond to number of rows and columns and the last one digit to position on the plot that you will use to draw the data.

# %%
# Create a figure with 1x2 subplot and make the left subplot active
plt.subplot('121')

# Plot in blue the % of degrees awarded to women in the Physical Sciences
plt.plot(year, cs, color='blue')
plt.title('Computer Sciences')

# Make the right subplot active in the current 1x2 subplot grid
plt.subplot('122')

# Plot in red the % of degrees awarded to women in Computer Science
plt.plot(year, business, color='red')
plt.title('Business')

# Use plt.tight_layout() to improve the spacing between subplots
plt.tight_layout()
plt.show()

# %% [markdown]
# you can use it to plot more plots in larger grids of subplots of the same figure.
#
# Exercise : Here, you will make a 2×2 grid of subplots and plot the percentage of degrees awarded to women in Business (using `business`), in Computer Science (using `cs`), in Health Professions (using `health`), and in Education (using `education`).

# %%
health = data['Health Professions'].values
education = data['Education'].values

# %% [markdown]
# Solution:

# %%
plt.figure(figsize=(10,10)) #
#Create a figure with 2x2 subplot layout and make the top left subplot active
plt.subplot(2,2,1)

# Plot in blue the % of degrees awarded to women in the Business
plt.plot(year, business, color='blue')
plt.title('Business')

# Make the top right subplot active in the current 2x2 subplot grid 
plt.subplot(2,2,2)

# Plot in red the % of degrees awarded to women in Computer Science
plt.plot(year, cs, color='red')
plt.title('Computer Science')

# Make the bottom left subplot active in the current 2x2 subplot grid
plt.subplot(2,2,3)

# Plot in green the % of degrees awarded to women in Health Professions
plt.plot(year, health, color='green')
plt.title('Health Professions')

# Make the bottom right subplot active in the current 2x2 subplot grid
plt.subplot(2,2,4)

# Plot in yellow the % of degrees awarded to women in Education
plt.plot(year, education, color='yellow')
plt.title('Education')

# Improve the spacing between subplots and display them
plt.tight_layout()
plt.show()

# %% [markdown]
# ## Using xlim(), ylim()
#
# In this exercise, you will work with the matplotlib.pyplot interface to quickly set the x- and y-limits of your plots.
#
# You will now create the same figure as in the previous exercise using `plt.plot()`, this time setting the axis extents using `plt.xlim()` and `plt.ylim()`. These commands allow you to either zoom or expand the plot or to set the axis ranges to include important values (such as the origin)

# %%
# Plot the % of degrees awarded to women in Computer Science and the Physical Sciences
plt.plot(year,cs, color='red') 
plt.plot(year, business, color='blue')

# Add the axis labels
plt.xlabel('Year')
plt.ylabel('Degrees awarded to women (%)')

# Set the x-axis range
plt.xlim(1990,2010)

# Set the y-axis range
plt.ylim(15,55)
# Add a title and display the plot
plt.title('Degrees awarded to women (1990-2010)\nComputer Science (red)\nBusiness (blue)')
plt.show()

# Save the image as 'xlim_and_ylim.png'
plt.savefig('xlim_and_ylim.png')

# %% [markdown]
# ## Using axis()
#
# Using plt.xlim() and plt.ylim() are useful for setting the axis limits individually. In this exercise, you will see how you can pass a 4-tuple to plt.axis() to set limits for both axes at once. For example, plt.axis((1980,1990,0,75)) would set the extent of the x-axis to the period between 1980 and 1990, and would set the y-axis extent from 0 to 75% degrees award.

# %%
# Plot in blue the % of degrees awarded to women in Computer Science
plt.plot(year,cs, color='blue')

# Plot in red the % of degrees awarded to women in the Business
plt.plot(year, business,color='red')

# Set the x-axis and y-axis limits
plt.axis((1990,2010,15,55))

# Show the figure
plt.show()

# Save the figure as 'axis_limits.png'
plt.savefig('axis_limits.png')

# %% [markdown]
# ## Using legend()
# Legends are useful for distinguishing between multiple datasets displayed on common axes. The relevant data are created using specific line colors or markers in various plot commands. Using the keyword argument label in the plotting function associates a string to use in a legend. ![imagen](./img/legendsPosition.JPG)

# %%
# Specify the label 'Computer Science'
plt.plot(year, cs, color='red', label='Computer Science') 

# Specify the label 'Physical Sciences' 
plt.plot(year, business, color='blue', label='Business')

# Add a legend at the lower center
plt.legend(loc='lower center')

# Add axis labels and title
plt.xlabel('Year')
plt.ylabel('Enrollment (%)')
plt.title('Undergraduate enrollment of women')
plt.show()

# %% [markdown]
# ## Using annotate()
#
# It is often useful to annotate a simple plot to provide context. This makes the plot more readable and can highlight specific aspects of the data. Annotations like text and arrows can be used to emphasize specific observations.
#
# ![imagen](./img/annotate.JPG)
#
#
# For example, to enable an arrow, set arrowprops=dict(facecolor='black'). The arrow will point to the location given by xy and the text will appear at the location given by xytext.

# %%
# Compute the maximum enrollment of women in Computer Science: cs_max
cs_max = cs.max()

# Calculate the year in which there was maximum enrollment of women in Computer Science: yr_max
yr_max = year[cs.argmax()]

# Compute the maximum enrollment of women in Computer Science: cs_max
business_max = business.max()

# Calculate the year in which there was maximum enrollment of women in Computer Science: yr_max
business_yr_max = year[business.argmax()]
# Out:
# c:\users\gabriela\appdata\local\programs\python\python36\lib\site-packages\ipykernel_launcher.py:11: FutureWarning:
# The current behaviour of 'Series.argmax' is deprecated, use 'idxmax'
# instead.
# The behavior of 'argmax' will be corrected to return the positional
# maximum in the future. For now, use 'series.values.argmax' or
# 'np.argmax(np.array(values))' to get the position of the maximum
# row.
#   # This is added back by InteractiveShellApp.init_path()

# %%
# Plot with legend as before
plt.figure(figsize=(10,5))
plt.plot(year, cs, color='red', label='Computer Science') 
plt.plot(year, business, color='blue', label='Business')
plt.legend(loc='lower right')
plt.ylim(0,70)
# Add a black arrow annotation
plt.annotate('Maximun', xy = (yr_max, cs_max),
             xytext = (yr_max+5, cs_max+5),
             arrowprops=dict(facecolor='red',shrink=0.005))
plt.annotate('Maximun', xy = ( business_yr_max, business_max), 
             xytext = (business_yr_max+5, business_max+5),
             arrowprops=dict(facecolor='blue',shrink=0.005))
# Add axis labels and title
plt.xlabel('Year')
plt.ylabel('Enrollment (%)')
plt.title('Undergraduate enrollment of women')
plt.show()

# %% [markdown]
# Matplotlib comes with a number of different stylesheets to customize the overall look of different plots. To activate a particular stylesheet you can simply call  `plt.style.use()` with the name of the style sheet you want. To list all the available style sheets you can execute: `print(plt.style.available)`.

# %%
print(plt.style.available)
# Out:
# ['bmh', 'classic', 'dark_background', 'fast', 'fivethirtyeight', 'ggplot', 'grayscale', 'seaborn-bright', 'seaborn-colorblind', 'seaborn-dark-palette', 'seaborn-dark', 'seaborn-darkgrid', 'seaborn-deep', 'seaborn-muted', 'seaborn-notebook', 'seaborn-paper', 'seaborn-pastel', 'seaborn-poster', 'seaborn-talk', 'seaborn-ticks', 'seaborn-white', 'seaborn-whitegrid', 'seaborn', 'Solarize_Light2', 'tableau-colorblind10', '_classic_test']

# %%
plt.figure(figsize=(10,10))
# Set the style to 'ggplot'
plt.style.use('ggplot')

# Create a figure with 2x2 subplot layout
plt.subplot(2, 2, 1) 

# Plot the enrollment % of women in the Physical Sciences
plt.plot(year, business, color='blue')
plt.title('Business')
# Add annotation
bs_max = business.max()
yr_max = year[business.argmax()]
plt.annotate('Maximum', xy=(yr_max, bs_max), xytext=(yr_max-1, bs_max-5), arrowprops=dict(facecolor='black'))

# Plot the enrollment % of women in Computer Science
plt.subplot(2, 2, 2)
plt.plot(year, cs, color='red')
plt.title('Computer Science')

# Add annotation
cs_max = cs.max()
yr_max = year[cs.argmax()]
plt.annotate('Maximum', xy=(yr_max, cs_max), xytext=(yr_max-1, cs_max-5), arrowprops=dict(facecolor='black'))

# Plot the enrollmment % of women in Health professions
plt.subplot(2, 2, 3)
plt.plot(year, health, color='green')
plt.title('Health Professions')

hl_max = health.max()
yr_max = year[health.argmax()]
plt.annotate('Maximum', xy=(yr_max, hl_max), xytext=(yr_max-1, hl_max-2), arrowprops=dict(facecolor='black'))


# Plot the enrollment % of women in Education
plt.subplot(2, 2, 4)
plt.plot(year, education, color='yellow')
plt.title('Education')

# Add annotation
ed_max = education.max()
yr_max = year[education.argmax()]
plt.annotate('Maximum', xy=(yr_max, ed_max), xytext=(yr_max-1, ed_max-1), arrowprops=dict(facecolor='black'))


# Improve spacing between subplots and display them
#plt.tight_layout()
plt.show()
# Out:
# c:\users\gabriela\appdata\local\programs\python\python36\lib\site-packages\ipykernel_launcher.py:13: FutureWarning:
# The current behaviour of 'Series.argmax' is deprecated, use 'idxmax'
# instead.
# The behavior of 'argmax' will be corrected to return the positional
# maximum in the future. For now, use 'series.values.argmax' or
# 'np.argmax(np.array(values))' to get the position of the maximum
# row.
#   del sys.path[0]

# %% [markdown]
# ## Modifying styles
# Matplotlib comes with a number of different stylesheets to customize the overall look of different plots. To activate a particular stylesheet you can simply call plt.style.use() with the name of the style sheet you want. To list all the available style sheets you can execute: print(plt.style.available).

# %%
plt.close()
plt.figure(figsize=(10,10))
# Set the style to 'Solarize_Light2'
plt.style.use('Solarize_Light2')

# Create a figure with 2x2 subplot layout
plt.subplot(2, 2, 1) 
plt.plot(year, business, color='blue')
plt.title('Business')
yr_max = year[business.argmax()]
plt.annotate('Maximum', xy=(yr_max, bs_max), xytext=(yr_max-1, bs_max-5), arrowprops=dict(facecolor='black'))
plt.subplot(2, 2, 2)
plt.plot(year, cs, color='red')
plt.title('Computer Science')
yr_max = year[cs.argmax()]
plt.annotate('Maximum', xy=(yr_max, cs_max), xytext=(yr_max-1, cs_max-5), arrowprops=dict(facecolor='black'))
plt.subplot(2, 2, 3)
plt.plot(year, health, color='green')
plt.title('Health Professions')
yr_max = year[health.argmax()]
plt.annotate('Maximum', xy=(yr_max, hl_max), xytext=(yr_max-1, hl_max-2), arrowprops=dict(facecolor='black'))
plt.subplot(2, 2, 4)
plt.plot(year, education, color='yellow')
plt.title('Education')
yr_max = year[education.argmax()]
plt.annotate('Maximum', xy=(yr_max, ed_max), xytext=(yr_max-1, ed_max-1), arrowprops=dict(facecolor='black'))
plt.tight_layout()
plt.show()
# Out:
# c:\users\gabriela\appdata\local\programs\python\python36\lib\site-packages\ipykernel_launcher.py:10: FutureWarning:
# The current behaviour of 'Series.argmax' is deprecated, use 'idxmax'
# instead.
# The behavior of 'argmax' will be corrected to return the positional
# maximum in the future. For now, use 'series.values.argmax' or
# 'np.argmax(np.array(values))' to get the position of the maximum
# row.
#   # Remove the CWD from sys.path while we load stuff.

# %% [markdown]
# ## Generating meshes
#
# In order to visualize two-dimensional arrays of data, it is necessary to understand how to generate and manipulate 2-D arrays. Many Matplotlib plots support arrays as input and in particular, they support NumPy arrays. The NumPy library is the most widely-supported means for supporting numeric arrays in Python.

# %%
# Generate two 1-D arrays: u, v
u = np.linspace(-2, 2, 41)
v = np.linspace(-1,1,21)

# Generate 2-D arrays from u and v: X, Y
X,Y = np.meshgrid(u,v)

# Compute Z based on X and Y
Z = np.sin(3*np.sqrt(X**2 + Y**2)) 

# Display the resulting image with pcolor()
plt.pcolor(Z)
plt.colorbar()
plt.show()

# Save the figure to 'sine_mesh.png'
plt.savefig('sine_mesh.png')

# %%
print(Z.shape)
plt.close()
# Out:
# (21, 41)

# %%
Z = [[1,2,3],
    [4,5,6],
    [7,8,9]]
# Display the resulting image with pcolor()
plt.pcolor(Z)
plt.colorbar()
plt.show()

# %%
plt.close()
plt.pcolor(Z, cmap='Accent')
plt.colorbar()
plt.show()

# %% [markdown]
# ## Visualizing bivariate functions
#
# ### Contour & filled contour plots
# Although plt.imshow() or plt.pcolor() are often used to visualize a 2-D array in entirety, there are other ways of visualizing such data without displaying all the available sample values. One option is to use the array to compute contours that are visualized instead.
#
# Two types of contour plot supported by Matplotlib are plt.contour() and plt.contourf() where the former displays the contours as lines and the latter displayed filled areas between contours. Both these plotting commands accept a two dimensional array from which the appropriate contours are computed.

# %%
plt.close()
plt.style.use('bmh')
# Generate 2-D arrays from u and v: X, Y
X,Y = np.meshgrid(u,v)

# Compute Z based on X and Y
Z = np.sin(3*np.sqrt(X**2 + Y**2)) 

plt.figure(figsize=(13,10))

# Generate a default contour map of the array Z
plt.subplot(2,2,1)
plt.contour(X,Y,Z)
plt.colorbar()
# Generate a contour map with 20 contours
plt.subplot(2,2,2)
plt.contour(X,Y,Z,20)
plt.colorbar()
# Generate a default filled contour map of the array Z
plt.subplot(2,2,3)
plt.contourf(X,Y,Z)
plt.colorbar()
# Generate a default filled contour map with 20 contours
plt.subplot(2,2,4)
plt.contourf(X,Y,Z,20)
plt.colorbar()
# Improve the spacing between subplots
plt.tight_layout()

# Display the figure
plt.show()

# %% [markdown]
# ## Modifying colormaps
# When displaying a 2-D array with plt.imshow() or plt.pcolor(), the values of the array are mapped to a corresponding color. The set of colors used is determined by a colormap which smoothly maps values to colors, making it easy to understand the structure of the data at a glance.
#
# It is often useful to change the colormap from the default 'jet' colormap used by matplotlib. A good colormap is visually pleasing and conveys the structure of the data faithfully and in a way that makes sense for the application.
#
# + Some matplotlib colormaps have unique names such as 'jet', 'coolwarm', 'magma' and 'viridis'.
# + Others have a naming scheme based on overall color such as 'Greens', 'Blues', 'Reds', and 'Purples'.
# + Another four colormaps are based on the seasons, namely 'summer', 'autumn', 'winter' and 'spring'.
# + You can insert the option cmap=<name> into most matplotlib functions to change the color map of the resulting plot.

# %%
plt.close()
plt.style.use('classic')
plt.figure(figsize=(13,10))
# Create a filled contour plot with a color map of 'viridis'
plt.subplot(2,2,1)
plt.contourf(X,Y,Z,20, cmap='viridis')
plt.colorbar()
plt.title('Viridis')

# Create a filled contour plot with a color map of 'gray'
plt.subplot(2,2,2)
plt.contourf(X,Y,Z,20, cmap='gray')
plt.colorbar()
plt.title('Gray')

# Create a filled contour plot with a color map of 'autumn'
plt.subplot(2,2,3)
plt.contourf(X,Y,Z,20, cmap='autumn')
plt.colorbar()
plt.title('Autumn')

# Create a filled contour plot with a color map of 'winter'
plt.subplot(2,2,4)
plt.contourf(X,Y,Z,20, cmap='winter')
plt.colorbar()
plt.title('Winter')

# Improve the spacing between subplots and display them
plt.tight_layout()
plt.show()

# %% [markdown]
# ## Using hist2d()
#
# Given a set of ordered pairs describing data points, you can count the number of points with similar values to construct a two-dimensional histogram. This is similar to a one-dimensional histogram, but it describes the joint variation of two random variables rather than just one.
#
# In matplotlib, one function to visualize 2-D histograms is `plt.hist2d()`.
#
# + You specify the coordinates of the points using `plt.hist2d(x,y)` assuming x and y are two vectors of the same length.
# + You can specify the number of bins with the argument `bins=(nx, ny)` where nx is the number of bins to use in the horizontal direction and ny is the number of bins to use in the vertical direction.
# + You can specify the rectangular region in which the samples are counted in constructing the 2D histogram. The optional parameter required is `range=((xmin, xmax), (ymin, ymax))` where xmin and xmax are the respective lower and upper limits for the variables on the x-axis andymin and ymax are the respective lower and upper limits for the variables on the y-axis. Notice that the optional range argument can use nested tuples or lists.

# %%
data= pd.read_csv('./dataset/auto-mpg.csv')
data.head()
# Out:
#     mpg  cyl  displ   hp  weight  accel  yr  origin              name  color  \
# 0  18.0    6  250.0   88    3139   14.5  71      US      ford mustang    red
# 1   9.0    8  304.0  193    4732   18.5  70      US          hi 1200d  green
# 2  36.1    4   91.0   60    1800   16.4  78    Asia  honda civic cvcc   blue
# 3  18.5    6  250.0   98    3525   19.0  77      US      ford granada    red
# 4  34.3    4   97.0   78    2188   15.8  80  Europe         audi 4000   blue
#
#         size marker
# 0  27.370336      o
# 1  62.199511      o
# 2   9.000000      x
# 3  34.515625      o
# 4  13.298178      s

# %%
accel = data.accel.values
weight = data.weight.values
hp = data.hp.values
mpg = data.mpg.values
max_accel = np.max(accel)
max_weight = np.max(weight)
print('maxima acceleracion: ',max_accel)
print('maxima peso: ',max_weight)
min_accel = np.min(accel)
min_weight = np.min(weight)
print('minimo acceleracion: ',min_accel)
print('minimo peso: ',min_weight)
# Out:
# maxima acceleracion:  24.8
# maxima peso:  5140
# minimo acceleracion:  8.0
# minimo peso:  1613

# %%
# Generate a 2-D histogram
plt.hist2d(accel,weight,bins=(20,20),range=((min_accel,max_accel),(min_weight,max_weight)))

# Add a color bar to the histogram
plt.colorbar()

# Add labels, title, and display the plot
plt.xlabel('acceleration')
plt.ylabel('weight')
plt.title('hist2d() plot')
plt.show()

# %%
# Generate a 2d histogram with hexagonal bins
plt.hexbin(hp,mpg, gridsize=(15,12),extent=(40,235,8,48))

           
# Add a color bar to the histogram
plt.colorbar()

# Add labels, title, and display the plot
plt.xlabel('Horse power [hp]')
plt.ylabel('Miles per gallon [mpg]')
plt.title('hexbin() plot')
plt.show()
