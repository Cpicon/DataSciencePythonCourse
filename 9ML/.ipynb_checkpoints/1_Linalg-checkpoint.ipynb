# %% [markdown]
# # Algebra Lineal
#
# En general, el álgebra lineal estudia los espacios vectoriales. Estos constan de un conjunto de vectores y un conjunto de escalares que tienen estructura de campo. Para definir un espacio vectorial es necesario permitir una operación de suma y otra de productos entre escalares y vectores que satisfacen algunas propiedades. El álgebra lineal también estudia las transformaciones lineales.
#
#
# Dentro del contexto de este curso, el álgebra lineal permite realizar representaciones y operaciones de conjuntos de ecuaciones lineales y será útil para desarrollar diferentes conceptos y herramientas. Primero será relevante realizar algunas definiciones pertinentes. Tomemos por $M \in \mathbb{R}^{m\times m}$ una matriz de $m$ columnas y $n$ filas, donde las entradas de $A$ son números reales y por $v \in \mathbb{R}^{n}$ un vector con $n$ entradas. Se puede definir por convención como un vector $n$ dimensional o como una matriz con $n$ filas y una columna. Un vector fila, por su parte, se puede ver como una matriz con una fila y $n$ columnas. Ver una matriz como una colección de vectores columna o fila puede ser conveniente en muchos casos.

# %% [markdown]
# ## Multiplicación de matrices
#
# El producto de dos matrices $A\in \mathbb{R}^{m\times n}$ y $B \in \mathbb{R}^{n\times p}$ es la matriz
#
# \begin{equation}
# C=AB\in \mathbb{R}^{m\times p}
# \end{equation}
#
# donde
#
# \begin{equation}
# C_{ij}=\sum_{k=1}^{n}A_{ik}B_{kj}
# \end{equation}
#
# Es importante tener en cuenta que el número de columnas en A debe ser igual al número de filas en B.
#
# ## Producto entre vectores.
#
# Dados dos vectores $u,v\in \mathbb{R}^n$, se tiene que $u^{T}v$ o sea el producto interior o producto punto es un número real dado por
#
# \begin{equation}
# u^{T}v\in \mathbb{R}=\sum_{i=1}^{n}{x_i y_i}
# \end{equation}
#
# Se puede ver el producto interior como un caso particulas del producto matricial. Además siempre se tiene que $u^T v=v^T u$.
#
# También se puede definir el producto externo entre vectores (no necesariamente del mismo tamaño) $u\in \mathbb{R}^m$ y $v \in \mathbb{R}^n$ de manera que $uv^T \in \mathbb{R}^{m\times n}$ está definido como el producto externo entre los vectores. Y es una matriz cuyas entradas son $[uv^T]_{ij}=u_i v_j$.
#
# ## Producto entre matrices y vectores
#
# Dada una matriz $A\in \mathbb{R}^{m\times n}$ y un vector $u \in \mathbb{R}^n$, el product es un vector $v=Au \in \mathbb{R}^m$.
#
# También se puede entender $v$ como una combinación lineal de las columnas de $A$, donde los coeficientes de la combinación lineal están dados por las entradas de $u$.

# %% [markdown]
# # Operaciones básicas y propiedades.
#
# ## Matriz identidad y matrices diagonales
#
# La matriz identidad denotada como $I\in \mathbb{R}^{n\times n}$, es una matriz cuadrada con unos en la diagonal y ceros en todas las demás posiciones y tiene la propiedad que $AI=A=IA$, dado un $A\in \mathbb{R}^{M\times n}$. En general, se asumirá que las dimensiones de $I$ en $IA$ corresponderan también a las dimensiones de A.
#
# Una matriz diagonal es una matriz donde los elementos no diagonales son 0. Esto típicamente se denota como $D=diag{(d_1,d_1,...d_n)}$.

# %% [markdown]
# # Operaciones básicas y propiedades.
#
# ## Transpuesta
#
# La transpuesta de una matriz $A\in \mathbb{R}^{m\times n}$ se escribe $A^T \in \mathbb{R}^{n\times m}$, cuyas entradas son $(A^T)_{ij}=A_{ji}$.
#
# Adicionalmente, se dice que una matriz $A$ es simétrica si $A=A^T$. Es antisimétrica si $A=-A^T$. Cualquier matriz cuadrada $n \times n$ puede ser representada como la suma de una matriz simétrica y una antisimétrica, ya que
#
# \begin{equation}
# A=\frac{1}{2} (A+A^T)+\frac{1}{2}(A-A^T)
# \end{equation}
#
# ## Traza
#
# La traza de una matriz cuadrada $A\in \mathbb{R}^{n \times n}$ denotada como $tr(A)$, es la suma de los elementos diagonales de la matriz $tr(A)=\sum_{i=1}^{n}A_{ii}$
#
# ## Normas
#
# La norma de un vector es informalmente una medida de la "longitud" de un vector. Por ejemplo. Usando la norma euclideana $l_2$, se tiene que
#
# \begin{equation}
# ||x||_2 =\sqrt{\sum_{i=1}^{n}{x_i}^2}
# \end{equation}
#
# Más formalmente, una norma es cualquier función $f:\mathbb{R^n}\rightarrow \mathbb{R}$ que satisface
#
# - Para todo $x\in \mathbb{R}^n$, $f(x)\geq 0$
# - $f(x)=0$ sí y sólo si $x=0$
# . Para todo $x \in \mathbb{R}^n$, $t\in \mathbb{R}$, $f(tx)=|t|f(x)$
# - Para todo $x,y\in\mathbb{R}^n$, $f(x+y)\leq f(x)+f(y)$
#
# ## Independencia lineal
#
# Un conjunto de vectores ${x_1,x_2,...,x_n}$ es linealmente independiente si ningún vector puede ser representado como una combinación lineal de los vectores restantes. De la misma manera si algún vector perteneciente al conjunto puede ser representado como una combinación lineal de los demás, entonces se dice que estos vectores son linealmente dependientes.

# %% [markdown]
# ## Inversa de una matriz cuadrada
#
# La inversa de una matriz cuadrada $A$ es denotada como $A^{-1}$ y es una matriz única tal que $A^{-1}A=I=AA^{-1}$. Claramente no todas las matrices tienen inversa. Las matrices que no son cuadradas no tienen inversa por definición. Las matrices cuadradas que no tienen inversa se denominan singulares.
#
# ## Matrices ortogonales
#
# Dos vectores $x,y\in \mathbb{R}^n$ son ortogonales si $x^Ty=0$. Una matriz $U$ es ortogonal si todas sus columnas son ortogonales entre sí. Por lo que $U^T U=I$.
#
# ## Determinante
#
# El determinante de una matriz cuadrada $A\in \mathbb{R}^{n\times n}$ es una función denotada como $det A$. Geométricamente, se puede interpretar el determinante como una medida del volumen del espacio $S^3$ generado al tomar todas las posibles combinaciones lineales de los vectores fila de una matriz A.
#
# - El determinante de la identidad es 1.
# - Dada una matriz A si se multiplica una sola fila por t, entonces el nuevo determinante es $tdet(A)$.
# - Si se intercambian dos filas, entonces el determinante de la nueva matriz es $-det(A)$.
#
# La formula general para el determinante es
# \begin{equation}
# |A|=\sum_{i=1}^{n} (-1)^{i+j} a_{ij} |A_{i,j}|
# \end{equation}
#
# A partir de esto, se puede definir la adjunta como
#
# \begin{equation}
# (adj(A))_{ij}=(-1)^{i+j} a_{ij} |A_{j,i}|
# \end{equation}
#
# # Formas cuadráticas y matrices positivas semidefinidas.
#
# Dada una matriz $A$, y un vector $x$, el valor escalar $x^T Ax$ es llamado una forma cuadrática. Es importante notar que $x^TAx=(x^TAx)^T=x^TA^T x=x^T(\frac{1}{2}A+\frac{1}{2}A^T)x$
#
# Por lo tanto sólo la parte simétrica contribuye a la forma cuadrática. Por lo tanto, se puede asumir que las matrices en forma cuadrática son simétricas.
#
# - Una matriz simétrica $A\in \mathbb{S}^n$ es positiva definida (PD) si para todos los vectores no cero $x\in \mathbb{R}$, $x^T Ax>0$.
#
# - Una matriz simétrica $A\in \mathbb{S}^n$ es positiva semidefinida (PSD) si para todos los vectores no cero $x\in \mathbb{R}$, $x^T Ax \geq 0$.
#
# -Una matriz simétrica $A\in \mathbb{S}^n$ es indefinida si no es ni positiva semidefinida ni negativa semidefinida (ie. si para todo $x$ no cero, $x\in \mathbb{R}$, $x^T Ax \geq 0$. ).
